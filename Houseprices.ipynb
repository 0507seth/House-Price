# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv(r'C:\Users\Partha\Dropbox\My PC (DESKTOP-ITT255T)\Downloads\houseprices.csv')
data.isnull().sum()
data.value_counts()
data.describe()
# Out:
#                Price  Living Area    Bathrooms     Bedrooms     Lot Size  \
# count    1047.000000  1047.000000  1047.000000  1047.000000  1047.000000
# mean   163862.125119  1807.302770     1.918338     3.183381     0.569580
# std     67651.558917   641.460916     0.641735     0.750265     0.777879
# min     16858.000000   672.000000     1.000000     1.000000     0.000000
# 25%    112014.000000  1336.000000     1.500000     3.000000     0.210000
# 50%    151917.000000  1672.000000     2.000000     3.000000     0.390000
# 75%    205235.000000  2206.000000     2.500000     4.000000     0.600000
# max    446436.000000  4534.000000     4.500000     6.000000     9.000000
#
#                Age    Fireplace
# count  1047.000000  1047.000000
# mean     28.061127     0.593123
# std      34.900899     0.491486
# min       0.000000     0.000000
# 25%       6.000000     0.000000
# 50%      18.000000     1.000000
# 75%      34.000000     1.000000
# max     247.000000     1.000000

# %%
plt.bar(data.Bathrooms,data.Price)
plt.hist(data.Price,bins=10)
data.Price.max()
cor=data.corr()
sns.jointplot(x='Living Area',y='Price',data=data,kind='reg')
sns.jointplot(x='Lot Size',y='Price',data=data,kind='reg')
sns.jointplot(x='Bathrooms',y='Price',data=data,kind='reg')
sns.jointplot(x='Bedrooms',y='Price',data=data,kind='reg')
sns.jointplot(x='Fireplace',y='Price',data=data,kind='reg')
sns.jointplot(x='Age',y='Price',data=data,kind='reg')
sns.pairplot(data)

# %%
var = 'Bedrooms'
df = pd.concat([data['Price'], data[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="Price", data=df)
fig.axis(ymin=0, ymax=500000);

# %%
sns.countplot(x=data['Bathrooms'])
sns.countplot(x=data['Bedrooms'])
sns.countplot(x=data['Age'])
sns.countplot(x=data['Fireplace'])
sns.distplot(data['Price'])
sns.distplot(data['Lot Size'])
sns.distplot(data['Living Area'])
sns.heatmap(data.corr())

sns.boxplot(data['Living Area'])
plt.hist(data['Living Area'],bins=50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bathrooms'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-93334c4fb353> in <module>
# ...

# %%
# Value Assigning

y=data.iloc[:,0]
X=data.iloc[:,1:7]

from sklearn.model_selection import train_test_split

X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
X_train=np.array(X_train)
X_test=np.array(X_test)

from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)

y_pred=model.predict(X_test)

from sklearn.metrics import mean_squared_error,r2_score

print(r2_score(y_test,y_pred))
print(np.round(model.coef_,4))

model.intercept_
# Out:
# 0.6289760151493399
# [   64.2493 17834.279  -3417.3588  1395.896   -217.7046  9517.7328]
# 22865.518060284434

# %%
X
# Out:
#       Living Area  Bathrooms  Bedrooms  Lot Size  Age  Fireplace
# 0            1982        1.0         3      2.00  133          0
# 1            1676        1.5         3      0.38   14          1
# 2            1694        2.0         3      0.96   15          1
# 3            1800        1.0         2      0.48   49          1
# 4            2088        1.0         3      1.84   29          1
# ...           ...        ...       ...       ...  ...        ...
# 1042         1802        2.0         4      0.97   56          1
# 1043         3239        3.5         4      2.50    1          1
# 1044         1440        2.0         2      0.61   66          1
# 1045         2030        2.5         3      1.00    3          1
# 1046         2097        2.5         3      1.93   10          1
#
# [1047 rows x 6 columns]
